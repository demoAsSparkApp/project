# %%
import os
import sys

sys.path.append(os.path.abspath(os.path.join(os.path.dirname("__file__"), "../../")))

from config import settings
from pyspark.sql import SparkSession
from pyspark.sql.functions import col, trim
import os
from src.config.spark_config import get_spark_session


from pyspark.sql import SparkSession
# Optional: custom tuning for this session
custom_tuning = {
    "spark.executor.memory": "6g",
    "spark.driver.memory": "4g",
    "spark.executor.cores": "4",
    "spark.sql.shuffle.partitions": "8",
    "spark.default.parallelism": "8",
    "spark.sql.adaptive.enabled": "true",
    "spark.sql.autoBroadcastJoinThreshold": "-1"
}

# Step 1: Start Spark session
from src.config.spark_config import get_spark_session
spark = get_spark_session(app_name="Read_Parquet_Tuning", custom_config=custom_tuning)
# Step 2: Define Parquet folder path
parquet_base = os.path.join(settings.BASE_DIR, "data", "parquet_data")

# Step 3: Map your Parquet files
parquet_files = {
    "title_basics": os.path.join(parquet_base, "title_basics.parquet"),
    "title_crew": os.path.join(parquet_base, "title_crew.parquet"),
    "title_episode": os.path.join(parquet_base, "title_episode.parquet"),
    "title_akas": os.path.join(parquet_base, "title_akas.parquet")
}
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# 25/06/22 23:53:54 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# /Users/aryan/Desktop/project/venv/lib/python3.9/site-packages/google/rpc/__init__.py:18: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources

# %%
from pyspark.sql.functions import col

# Define which column to select for each file
columns_to_display = {
    "title_basics": "primaryTitle",
    "title_crew": "directors",
    "title_episode": "seasonNumber",
    "title_akas": "title"
}

# Load and display the specified column for each file
for name, path in parquet_files.items():
    print(f"📄 Reading file: {name}")
    column = columns_to_display[name]

    df = spark.read.parquet(path)
    
    if column in df.columns:
        df.select(col(column)).show(5)
    else:
        print(f"❌ Column '{column}' not found in {name}")
# Out:
# 📄 Reading file: title_basics
# +--------------------+
# |        primaryTitle|
# +--------------------+
# |McCraw vs. Herrin...|
# |          Ed Genesis|
# |    Aikens vs. Brown|
# |From Marshes to M...|
# |     Orive vs. Stark|
# +--------------------+
# only showing top 5 rows
# 📄 Reading file: title_crew
# +---------+
# |directors|
# +---------+
# |nm0808310|
# |       \N|
# |       \N|
# |nm0011612|
# |nm0011612|
# +---------+
# only showing top 5 rows
# 📄 Reading file: title_episode
# +------------+
# |seasonNumber|
# +------------+
# |          \N|
# |           1|
# |           1|
# |          \N|
# |           2|
# +------------+
# only showing top 5 rows
# 📄 Reading file: title_akas
# +--------------------+
# |               title|
# +--------------------+
# |          Carmencita|
# |          Carmencita|
# |          Carmencita|
# |Carmencita - span...|
# |          Καρμενσίτα|
# +--------------------+
# only showing top 5 rows

# %%
from pyspark.sql.functions import col
#filter
path = parquet_files["title_basics"]
df = spark.read.parquet(path)

# ✅ Basic Query - Pushdown Filter Example
basic_filtered = df.filter(col("titleType") == "movie")
print("🔍 BASIC FILTER - Only movies")
basic_filtered.explain(mode="formatted")
basic_filtered.show(1, truncate=False)
# Out:
# 🔍 BASIC FILTER - Only movies
# == Physical Plan ==
# * Filter (3)
# +- * ColumnarToRow (2)
#    +- Scan parquet  (1)
#
#
# (1) Scan parquet
# Output [11]: [tconst#570, titleType#571, primaryTitle#572, originalTitle#573, isAdult#574, startYear#575, endYear#576, runtimeMinutes#577, genre_1#578, genre_2#579, ingested_at#580]
# Batched: true
# Location: InMemoryFileIndex [file:/Users/aryan/Desktop/project/data/parquet_data/title_basics.parquet]
# PushedFilters: [IsNotNull(titleType), EqualTo(titleType,movie)]
# ReadSchema: struct<tconst:string,titleType:string,primaryTitle:string,originalTitle:string,isAdult:string,startYear:string,endYear:string,runtimeMinutes:string,genre_1:string,genre_2:string,ingested_at:string>
#
# (2) ColumnarToRow [codegen id : 1]
# Input [11]: [tconst#570, titleType#571, primaryTitle#572, originalTitle#573, isAdult#574, startYear#575, endYear#576, runtimeMinutes#577, genre_1#578, genre_2#579, ingested_at#580]
#
# (3) Filter [codegen id : 1]
# Input [11]: [tconst#570, titleType#571, primaryTitle#572, originalTitle#573, isAdult#574, startYear#575, endYear#576, runtimeMinutes#577, genre_1#578, genre_2#579, ingested_at#580]
# Condition : (isnotnull(titleType#571) AND (titleType#571 = movie))
#
#
# +----------+---------+---------------------+---------------------+-------+---------+-------+--------------+-----------+-------+-------------------+
# |tconst    |titleType|primaryTitle         |originalTitle        |isAdult|startYear|endYear|runtimeMinutes|genre_1    |genre_2|ingested_at        |
# +----------+---------+---------------------+---------------------+-------+---------+-------+--------------+-----------+-------+-------------------+
# |tt32444915|movie    |Lightning in a Bottle|Lightning in a Bottle|0      |\N       |\N     |90            |Documentary|NULL   |2025-06-22 23:11:21|
# +----------+---------+---------------------+---------------------+-------+---------+-------+--------------+-----------+-------+-------------------+
# only showing top 1 row

# %%
#level 2
# ✅ Advanced Query - Combined Pushdown Filter
advanced_filtered = df.filter(
    (col("titleType") == "movie") &
    (col("startYear") == "2024") &
    (col("genre_1") == "Drama")
)

print("🔍 ADVANCED FILTER - Movies from 2024 in Drama")
advanced_filtered.explain(mode="formatted")
advanced_filtered.show(1, truncate=False)
# Out:
# 🔍 ADVANCED FILTER - Movies from 2024 in Drama
# == Physical Plan ==
# * Filter (3)
# +- * ColumnarToRow (2)
#    +- Scan parquet  (1)
#
#
# (1) Scan parquet
# Output [11]: [tconst#570, titleType#571, primaryTitle#572, originalTitle#573, isAdult#574, startYear#575, endYear#576, runtimeMinutes#577, genre_1#578, genre_2#579, ingested_at#580]
# Batched: true
# Location: InMemoryFileIndex [file:/Users/aryan/Desktop/project/data/parquet_data/title_basics.parquet]
# PushedFilters: [IsNotNull(titleType), IsNotNull(startYear), IsNotNull(genre_1), EqualTo(titleType,movie), EqualTo(startYear,2024), EqualTo(genre_1,Drama)]
# ReadSchema: struct<tconst:string,titleType:string,primaryTitle:string,originalTitle:string,isAdult:string,startYear:string,endYear:string,runtimeMinutes:string,genre_1:string,genre_2:string,ingested_at:string>
#
# (2) ColumnarToRow [codegen id : 1]
# Input [11]: [tconst#570, titleType#571, primaryTitle#572, originalTitle#573, isAdult#574, startYear#575, endYear#576, runtimeMinutes#577, genre_1#578, genre_2#579, ingested_at#580]
#
# (3) Filter [codegen id : 1]
# Input [11]: [tconst#570, titleType#571, primaryTitle#572, originalTitle#573, isAdult#574, startYear#575, endYear#576, runtimeMinutes#577, genre_1#578, genre_2#579, ingested_at#580]
# Condition : (((((isnotnull(titleType#571) AND isnotnull(startYear#575)) AND isnotnull(genre_1#578)) AND (titleType#571 = movie)) AND (startYear#575 = 2024)) AND (genre_1#578 = Drama))
#
#
# +----------+---------+---------------+---------------+-------+---------+-------+--------------+-------+-------+-------------------+
# |tconst    |titleType|primaryTitle   |originalTitle  |isAdult|startYear|endYear|runtimeMinutes|genre_1|genre_2|ingested_at        |
# +----------+---------+---------------+---------------+-------+---------+-------+--------------+-------+-------+-------------------+
# |tt32444916|movie    |A Night of Fate|A Night of Fate|0      |2024     |\N     |54            |Drama  |NULL   |2025-06-22 23:11:21|
# +----------+---------+---------------+---------------+-------+---------+-------+--------------+-------+-------+-------------------+
# only showing top 1 row

# %%
df_no_pushdown = spark.read.parquet(path)
df_filtered = df_no_pushdown.filter(col("titleType") == "movie")

df_filtered.explain(mode="formatted")
df_filtered.show(1, truncate=False)
# Out:
# == Physical Plan ==
# * Filter (3)
# +- * ColumnarToRow (2)
#    +- Scan parquet  (1)
#
#
# (1) Scan parquet
# Output [11]: [tconst#650, titleType#651, primaryTitle#652, originalTitle#653, isAdult#654, startYear#655, endYear#656, runtimeMinutes#657, genre_1#658, genre_2#659, ingested_at#660]
# Batched: true
# Location: InMemoryFileIndex [file:/Users/aryan/Desktop/project/data/parquet_data/title_basics.parquet]
# PushedFilters: [IsNotNull(titleType), EqualTo(titleType,movie)]
# ReadSchema: struct<tconst:string,titleType:string,primaryTitle:string,originalTitle:string,isAdult:string,startYear:string,endYear:string,runtimeMinutes:string,genre_1:string,genre_2:string,ingested_at:string>
#
# (2) ColumnarToRow [codegen id : 1]
# Input [11]: [tconst#650, titleType#651, primaryTitle#652, originalTitle#653, isAdult#654, startYear#655, endYear#656, runtimeMinutes#657, genre_1#658, genre_2#659, ingested_at#660]
#
# (3) Filter [codegen id : 1]
# Input [11]: [tconst#650, titleType#651, primaryTitle#652, originalTitle#653, isAdult#654, startYear#655, endYear#656, runtimeMinutes#657, genre_1#658, genre_2#659, ingested_at#660]
# Condition : (isnotnull(titleType#651) AND (titleType#651 = movie))
#
#
# +----------+---------+---------------------+---------------------+-------+---------+-------+--------------+-----------+-------+-------------------+
# |tconst    |titleType|primaryTitle         |originalTitle        |isAdult|startYear|endYear|runtimeMinutes|genre_1    |genre_2|ingested_at        |
# +----------+---------+---------------------+---------------------+-------+---------+-------+--------------+-----------+-------+-------------------+
# |tt32444915|movie    |Lightning in a Bottle|Lightning in a Bottle|0      |\N       |\N     |90            |Documentary|NULL   |2025-06-22 23:11:21|
# +----------+---------+---------------------+---------------------+-------+---------+-------+--------------+-----------+-------+-------------------+
# only showing top 1 row

# %%
# # User Code (DataFrame API)

# Logical Plan (What to do)
# >>>Optimized Logical Plan (Simplified version)
#         ↓
# >>>Physical Plan (How to do it)
#         ↓
# >>> Executed by Spark Engine

# %%
from pyspark.sql.functions import col

# Read Parquet files
title_basics = spark.read.parquet(parquet_files["title_basics"])
title_crew = spark.read.parquet(parquet_files["title_crew"])

# Apply early filter to reduce data before join (pushdown)
filtered_basics = title_basics.filter(col("titleType") == "movie")

# Perform join
joined_df = filtered_basics.join(title_crew, on="tconst", how="inner")

# Select and display a few useful columns
result_df = joined_df.select("tconst", "primaryTitle", "directors", "writers")

# Show 5 records
result_df.show(5, truncate=False)

# Print physical plan
result_df.explain(mode="formatted")
# Out:
# [Stage 24:==================================================>       (7 + 1) / 8]
# +---------+--------------------------------+---------+---------+
# |tconst   |primaryTitle                    |directors|writers  |
# +---------+--------------------------------+---------+---------+
# |tt0000591|The Prodigal Son                |nm0141150|nm0141150|
# |tt0000867|Fiesta de toros                 |nm0023107|\N       |
# |tt0000868|Fiestas de Santa Lucía - Belenes|nm0005717|nm0005717|
# |tt0000886|Hamlet                          |nm0099901|nm0000636|
# |tt0001007|La primera y segunda casetas    |nm0185426|\N       |
# +---------+--------------------------------+---------+---------+
# only showing top 5 rows
# == Physical Plan ==
# AdaptiveSparkPlan (12)
# +- Project (11)
#    +- SortMergeJoin Inner (10)
#       :- Sort (5)
#       :  +- Exchange (4)
#       :     +- Project (3)
#       :        +- Filter (2)
#       :           +- Scan parquet  (1)
#       +- Sort (9)
#          +- Exchange (8)
#             +- Filter (7)
#                +- Scan parquet  (6)
#
#
# (1) Scan parquet
# Output [3]: [tconst#696, titleType#697, primaryTitle#698]
# Batched: true
# Location: InMemoryFileIndex [file:/Users/aryan/Desktop/project/data/parquet_data/title_basics.parquet]
# PushedFilters: [IsNotNull(titleType), EqualTo(titleType,movie), IsNotNull(tconst)]
# ReadSchema: struct<tconst:string,titleType:string,primaryTitle:string>
#
# (2) Filter
# Input [3]: [tconst#696, titleType#697, primaryTitle#698]
# Condition : ((isnotnull(titleType#697) AND (titleType#697 = movie)) AND isnotnull(tconst#696))
#
# (3) Project
# Output [2]: [tconst#696, primaryTitle#698]
# Input [3]: [tconst#696, titleType#697, primaryTitle#698]
#
# (4) Exchange
# Input [2]: [tconst#696, primaryTitle#698]
# Arguments: hashpartitioning(tconst#696, 8), ENSURE_REQUIREMENTS, [plan_id=394]
#
# (5) Sort
# Input [2]: [tconst#696, primaryTitle#698]
# Arguments: [tconst#696 ASC NULLS FIRST], false, 0
#
# (6) Scan parquet
# Output [3]: [tconst#707, directors#708, writers#709]
# Batched: true
# Location: InMemoryFileIndex [file:/Users/aryan/Desktop/project/data/parquet_data/title_crew.parquet]
# PushedFilters: [IsNotNull(tconst)]
# ReadSchema: struct<tconst:string,directors:string,writers:string>
#
# (7) Filter
# Input [3]: [tconst#707, directors#708, writers#709]
# Condition : isnotnull(tconst#707)
#
# (8) Exchange
# Input [3]: [tconst#707, directors#708, writers#709]
# Arguments: hashpartitioning(tconst#707, 8), ENSURE_REQUIREMENTS, [plan_id=395]
#
# (9) Sort
# Input [3]: [tconst#707, directors#708, writers#709]
# Arguments: [tconst#707 ASC NULLS FIRST], false, 0
#
# (10) SortMergeJoin
# Left keys [1]: [tconst#696]
# Right keys [1]: [tconst#707]
# Join type: Inner
# Join condition: None
#
# (11) Project
# Output [4]: [tconst#696, primaryTitle#698, directors#708, writers#709]
# Input [5]: [tconst#696, primaryTitle#698, tconst#707, directors#708, writers#709]
#
# (12) AdaptiveSparkPlan
# Output [4]: [tconst#696, primaryTitle#698, directors#708, writers#709]
# Arguments: isFinalPlan=false

# %%
# Filter early to reduce join data size.
# 	•	Avoid joins on huge unsorted datasets without bucketing/salting.
# 	•	Use broadcast() on smaller DF to trigger Broadcast Join if needed.

# %%
from pyspark.sql.functions import split, explode, trim

# Step 1: Load data
title_basics = spark.read.parquet(parquet_files["title_basics"])
title_crew = spark.read.parquet(parquet_files["title_crew"])
name_basics = spark.read.parquet(os.path.join(parquet_base, "name_basics.parquet"))

# Step 2: Filter only movies
movies = title_basics.filter(col("titleType") == "movie")

# Step 3: Join title_basics + title_crew
crew_joined = movies.join(title_crew, on="tconst", how="inner")

# Step 4: Explode director IDs (split on comma)
directors_df = crew_joined \
    .withColumn("director_id", explode(split(col("directors"), ","))) \
    .drop("writers")  # Optional

# Step 5: Join with name_basics to get actual names
final_df = directors_df.join(name_basics, directors_df.director_id == name_basics.nconst, how="left") \
    .select("tconst", "primaryTitle", "director_id", "primaryName") \
    .withColumnRenamed("primaryName", "director_name")

# Step 6: Show
final_df.show(5, truncate=False)
# Out:
# +---------+-----------------------------+-----------+-----------------------------------+
# |tconst   |primaryTitle                 |director_id|director_name                      |
# +---------+-----------------------------+-----------+-----------------------------------+
# |tt0000675|Don Quijote                  |nm0194088  |Narciso Cuyàs                      |
# |tt0000147|The Corbett-Fitzsimmons Fight|nm0714557  |Enoch J. Rector                    |
# |tt0001422|Trail to the West            |nm0001908  |Gilbert M. 'Broncho Billy' Anderson|
# |tt0000838|A Cultura do Cacau           |nm0017074  |Ernesto de Albuquerque             |
# |tt0000850|Los dos hermanos             |nm0063413  |Ricardo de Baños                   |
# +---------+-----------------------------+-----------+-----------------------------------+
# only showing top 5 rows

# %%
df = title_basics.filter(col("titleType") == "movie")
df.explain(mode="formatted")
# Out:
# == Physical Plan ==
# * Filter (3)
# +- * ColumnarToRow (2)
#    +- Scan parquet  (1)
#
#
# (1) Scan parquet
# Output [11]: [tconst#741, titleType#742, primaryTitle#743, originalTitle#744, isAdult#745, startYear#746, endYear#747, runtimeMinutes#748, genre_1#749, genre_2#750, ingested_at#751]
# Batched: true
# Location: InMemoryFileIndex [file:/Users/aryan/Desktop/project/data/parquet_data/title_basics.parquet]
# PushedFilters: [IsNotNull(titleType), EqualTo(titleType,movie)]
# ReadSchema: struct<tconst:string,titleType:string,primaryTitle:string,originalTitle:string,isAdult:string,startYear:string,endYear:string,runtimeMinutes:string,genre_1:string,genre_2:string,ingested_at:string>
#
# (2) ColumnarToRow [codegen id : 1]
# Input [11]: [tconst#741, titleType#742, primaryTitle#743, originalTitle#744, isAdult#745, startYear#746, endYear#747, runtimeMinutes#748, genre_1#749, genre_2#750, ingested_at#751]
#
# (3) Filter [codegen id : 1]
# Input [11]: [tconst#741, titleType#742, primaryTitle#743, originalTitle#744, isAdult#745, startYear#746, endYear#747, runtimeMinutes#748, genre_1#749, genre_2#750, ingested_at#751]
# Condition : (isnotnull(titleType#742) AND (titleType#742 = movie))

# %%
df = title_basics.filter(col("titleType") == "movie")

# Logical plan (developer-friendly)
print(df._jdf.queryExecution().logical())

# Optimized plan (after Catalyst optimizations)
print(df._jdf.queryExecution().optimizedPlan())

# Physical plan (actual execution)
print(df._jdf.queryExecution().executedPlan())
# Out:
# 'Filter '`=`('titleType, movie)
# +- Relation [tconst#741,titleType#742,primaryTitle#743,originalTitle#744,isAdult#745,startYear#746,endYear#747,runtimeMinutes#748,genre_1#749,genre_2#750,ingested_at#751] parquet
#
# Filter (isnotnull(titleType#742) AND (titleType#742 = movie))
# +- Relation [tconst#741,titleType#742,primaryTitle#743,originalTitle#744,isAdult#745,startYear#746,endYear#747,runtimeMinutes#748,genre_1#749,genre_2#750,ingested_at#751] parquet
#
# *(1) Filter (isnotnull(titleType#742) AND (titleType#742 = movie))
# +- *(1) ColumnarToRow
#    +- FileScan parquet [tconst#741,titleType#742,primaryTitle#743,originalTitle#744,isAdult#745,startYear#746,endYear#747,runtimeMinutes#748,genre_1#749,genre_2#750,ingested_at#751] Batched: true, DataFilters: [isnotnull(titleType#742), (titleType#742 = movie)], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/Users/aryan/Desktop/project/data/parquet_data/title_basics.parquet], PartitionFilters: [], PushedFilters: [IsNotNull(titleType), EqualTo(titleType,movie)], ReadSchema: struct<tconst:string,titleType:string,primaryTitle:string,originalTitle:string,isAdult:string,sta...

# %%
from pyspark.sql.functions import col
# Get All Movie Titles with Their Directors & Writers
title_basics = spark.read.parquet(parquet_files["title_basics"])
title_crew = spark.read.parquet(parquet_files["title_crew"])

# %%
movies_df = title_basics.filter(col("titleType") == "movie").select("tconst", "primaryTitle")

# %%
movie_crew_df = movies_df.join(
    title_crew,
    on="tconst",
    how="inner"
).select("tconst", "primaryTitle", "directors", "writers")

# %%
# EXPLAIN plan
movie_crew_df.explain(mode="formatted")

# Query Execution Details
print("\n🧠 Logical Plan:")
print(movie_crew_df._jdf.queryExecution().logical())

print("\n🛠 Optimized Plan:")
print(movie_crew_df._jdf.queryExecution().optimizedPlan())

print("\n⚙️ Physical Plan:")
print(movie_crew_df._jdf.queryExecution().executedPlan())
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (12)
# +- Project (11)
#    +- SortMergeJoin Inner (10)
#       :- Sort (5)
#       :  +- Exchange (4)
#       :     +- Project (3)
#       :        +- Filter (2)
#       :           +- Scan parquet  (1)
#       +- Sort (9)
#          +- Exchange (8)
#             +- Filter (7)
#                +- Scan parquet  (6)
#
#
# (1) Scan parquet
# Output [3]: [tconst#790, titleType#791, primaryTitle#792]
# Batched: true
# Location: InMemoryFileIndex [file:/Users/aryan/Desktop/project/data/parquet_data/title_basics.parquet]
# PushedFilters: [IsNotNull(titleType), EqualTo(titleType,movie), IsNotNull(tconst)]
# ReadSchema: struct<tconst:string,titleType:string,primaryTitle:string>
#
# (2) Filter
# Input [3]: [tconst#790, titleType#791, primaryTitle#792]
# Condition : ((isnotnull(titleType#791) AND (titleType#791 = movie)) AND isnotnull(tconst#790))
#
# (3) Project
# Output [2]: [tconst#790, primaryTitle#792]
# Input [3]: [tconst#790, titleType#791, primaryTitle#792]
#
# (4) Exchange
# Input [2]: [tconst#790, primaryTitle#792]
# Arguments: hashpartitioning(tconst#790, 8), ENSURE_REQUIREMENTS, [plan_id=802]
#
# (5) Sort
# Input [2]: [tconst#790, primaryTitle#792]
# Arguments: [tconst#790 ASC NULLS FIRST], false, 0
#
# (6) Scan parquet
# Output [3]: [tconst#801, directors#802, writers#803]
# Batched: true
# Location: InMemoryFileIndex [file:/Users/aryan/Desktop/project/data/parquet_data/title_crew.parquet]
# PushedFilters: [IsNotNull(tconst)]
# ReadSchema: struct<tconst:string,directors:string,writers:string>
#
# (7) Filter
# Input [3]: [tconst#801, directors#802, writers#803]
# Condition : isnotnull(tconst#801)
#
# (8) Exchange
# Input [3]: [tconst#801, directors#802, writers#803]
# Arguments: hashpartitioning(tconst#801, 8), ENSURE_REQUIREMENTS, [plan_id=803]
#
# (9) Sort
# Input [3]: [tconst#801, directors#802, writers#803]
# Arguments: [tconst#801 ASC NULLS FIRST], false, 0
#
# (10) SortMergeJoin
# Left keys [1]: [tconst#790]
# Right keys [1]: [tconst#801]
# Join type: Inner
# Join condition: None
#
# (11) Project
# Output [4]: [tconst#790, primaryTitle#792, directors#802, writers#803]
# Input [5]: [tconst#790, primaryTitle#792, tconst#801, directors#802, writers#803]
#
# (12) AdaptiveSparkPlan
# Output [4]: [tconst#790, primaryTitle#792, directors#802, writers#803]
# Arguments: isFinalPlan=false
#
#
#
# 🧠 Logical Plan:
# 'Project ['tconst, 'primaryTitle, 'directors, 'writers]
# +- Project [tconst#790, primaryTitle#792, directors#802, writers#803, ingested_at#804]
#    +- Join Inner, (tconst#790 = tconst#801)
#       :- Project [tconst#790, primaryTitle#792]
#       :  +- Filter (titleType#791 = movie)
#       :     +- Relation [tconst#790,titleType#791,primaryTitle#792,originalTitle#793,isAdult#794,startYear#795,endYear#796,runtimeMinutes#797,genre_1#798,genre_2#799,ingested_at#800] parquet
#       +- Relation [tconst#801,directors#802,writers#803,ingested_at#804] parquet
#
#
# 🛠 Optimized Plan:
# Project [tconst#790, primaryTitle#792, directors#802, writers#803]
# +- Join Inner, (tconst#790 = tconst#801)
#    :- Project [tconst#790, primaryTitle#792]
#    :  +- Filter ((isnotnull(titleType#791) AND (titleType#791 = movie)) AND isnotnull(tconst#790))
#    :     +- Relation [tconst#790,titleType#791,primaryTitle#792,originalTitle#793,isAdult#794,startYear#795,endYear#796,runtimeMinutes#797,genre_1#798,genre_2#799,ingested_at#800] parquet
#    +- Project [tconst#801, directors#802, writers#803]
#       +- Filter isnotnull(tconst#801)
#          +- Relation [tconst#801,directors#802,writers#803,ingested_at#804] parquet
#
#
# ⚙️ Physical Plan:
# AdaptiveSparkPlan isFinalPlan=false
# +- Project [tconst#790, primaryTitle#792, directors#802, writers#803]
#    +- SortMergeJoin [tconst#790], [tconst#801], Inner
#       :- Sort [tconst#790 ASC NULLS FIRST], false, 0
#       :  +- Exchange hashpartitioning(tconst#790, 8), ENSURE_REQUIREMENTS, [plan_id=802]
#       :     +- Project [tconst#790, primaryTitle#792]
#       :        +- Filter ((isnotnull(titleType#791) AND (titleType#791 = movie)) AND isnotnull(tconst#790))
#       :           +- FileScan parquet [tconst#790,titleType#791,primaryTitle#792] Batched: true, DataFilters: [isnotnull(titleType#791), (titleType#791 = movie), isnotnull(tconst#790)], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/Users/aryan/Desktop/project/data/parquet_data/title_basics.parquet], PartitionFilters: [], PushedFilters: [IsNotNull(titleType), EqualTo(titleType,movie), IsNotNull(tconst)], ReadSchema: struct<tconst:string,titleType:string,primaryTitle:string>
#       +- Sort [tconst#801 ASC NULLS FIRST], false, 0
#          +- Exchange hashpartitioning(tconst#801, 8), ENSURE_REQUIREMENTS, [plan_id=803]
#             +- Filter isnotnull(tconst#801)
#                +- FileScan parquet [tconst#801,directors#802,writers#803] Batched: true, DataFilters: [isnotnull(tconst#801)], Format: Parquet, Location: InMemoryFileIndex(1 paths)[file:/Users/aryan/Desktop/project/data/parquet_data/title_crew.parquet], PartitionFilters: [], PushedFilters: [IsNotNull(tconst)], ReadSchema: struct<tconst:string,directors:string,writers:string>

# %%
movie_crew_df.show(5, truncate=False)
# Out:
# [Stage 53:====================================>                     (5 + 3) / 8]
# +---------+--------------------------------+---------+---------+
# |tconst   |primaryTitle                    |directors|writers  |
# +---------+--------------------------------+---------+---------+
# |tt0000591|The Prodigal Son                |nm0141150|nm0141150|
# |tt0000867|Fiesta de toros                 |nm0023107|\N       |
# |tt0000868|Fiestas de Santa Lucía - Belenes|nm0005717|nm0005717|
# |tt0000886|Hamlet                          |nm0099901|nm0000636|
# |tt0001007|La primera y segunda casetas    |nm0185426|\N       |
# +---------+--------------------------------+---------+---------+
# only showing top 5 rows

# %%
title_basics = spark.read.parquet(parquet_files["title_basics"])
title_crew = spark.read.parquet(parquet_files["title_crew"])
title_akas = spark.read.parquet(parquet_files["title_akas"])
name_basics = spark.read.parquet(os.path.join(parquet_base, "name_basics.parquet"))

# %%
title_ratings = spark.read.parquet(os.path.join(parquet_base, "title_ratings.parquet"))

# %%
# Filter High-Rated Movies (Predicate Pushdown)
high_rated = title_ratings.filter(col("averageRating") >= 8.5)

# %%
high_rated_movies = high_rated.join(
    title_basics.filter(col("titleType") == "movie"),
    on="tconst",
    how="inner"
)

# %%
movie_with_crew = high_rated_movies.join(title_crew, on="tconst", how="left")

# %%
from pyspark.sql.functions import split, explode

# Explode director IDs (comma-separated)
movie_with_directors = movie_with_crew.withColumn("director_id", explode(split(col("directors"), ",")))

# Join with name_basics
movie_with_director_names = movie_with_directors.join(
    name_basics.select(col("nconst").alias("director_id"), col("primaryName")),
    on="director_id",
    how="left"
)

# %%
final_df = movie_with_director_names.join(
    title_akas.select("titleId", "title", "region"),
    movie_with_director_names.tconst == title_akas.titleId,
    how="left"
).drop("titleId")

# %%
final_df.cache()
# Out:
# DataFrame[director_id: string, tconst: string, averageRating: double, numVotes: int, ingested_at: string, titleType: string, primaryTitle: string, originalTitle: string, isAdult: string, startYear: string, endYear: string, runtimeMinutes: string, genre_1: string, genre_2: string, ingested_at: string, directors: string, writers: string, ingested_at: string, primaryName: string, title: string, region: string]

# %%
# Use cache() when this DF is reused multiple times
# 	•	❌ Don’t cache unnecessarily (it eats memory)

# %%
# Final cleanup
output_df = final_df.select("primaryTitle", "primaryName", "averageRating", "region", "title")

# Optional: reduce partitions for small result set
output_df = output_df.coalesce(1)

# Save or display
output_df.show(10, truncate=False)
# Out:
# [Stage 110:===================================>                     (5 + 3) / 8]
# +-------------------------+-------------+-------------+------+-------------------------+
# |primaryTitle             |primaryName  |averageRating|region|title                    |
# +-------------------------+-------------+-------------+------+-------------------------+
# |Powder                   |Arthur Maude |9.0          |\N    |Powder                   |
# |Powder                   |Arthur Maude |9.0          |US    |Powder                   |
# |The Monastery's Hunter   |Franz Osten  |8.5          |\N    |Der Klosterjäger         |
# |The Monastery's Hunter   |Franz Osten  |8.5          |HU    |A hegyek pásztora        |
# |The Monastery's Hunter   |Franz Osten  |8.5          |DE    |Der Klosterjäger         |
# |The Monastery's Hunter   |Franz Osten  |8.5          |XWW   |The Monastery's Hunter   |
# |The Rider of the King Log|Harry O. Hoyt|8.5          |\N    |The Rider of the King Log|
# |The Rider of the King Log|Harry O. Hoyt|8.5          |GB    |The Rider of the King Log|
# |The Rider of the King Log|Harry O. Hoyt|8.5          |US    |The Rider of the King Log|
# |The Rider of the King Log|Harry O. Hoyt|8.5          |NL    |De heerscher van het woud|
# +-------------------------+-------------+-------------+------+-------------------------+
# only showing top 10 rows

# %%
output_df.explain(mode="formatted")
# Out:
# == Physical Plan ==
# AdaptiveSparkPlan (81)
# +- Coalesce (80)
#    +- InMemoryTableScan (1)
#          +- InMemoryRelation (2)
#                +- AdaptiveSparkPlan (79)
#                   +- == Final Plan ==
#                      ResultQueryStage (49)
#                      +- * Project (48)
#                         +- * SortMergeJoin LeftOuter (47)
#                            :- * Sort (40)
#                            :  +- ShuffleQueryStage (39), Statistics(sizeInBytes=5.2 MiB, rowCount=1.32E+4)
#                            :     +- Exchange (38)
#                            :        +- * Project (37)
#                            :           +- * SortMergeJoin LeftOuter (36)
#                            :              :- * Sort (28)
#                            :              :  +- ShuffleQueryStage (27), Statistics(sizeInBytes=4.9 MiB, rowCount=1.32E+4)
#                            :              :     +- Exchange (26)
#                            :              :        +- * Generate (25)
#                            :              :           +- * Project (24)
#                            :              :              +- * SortMergeJoin LeftOuter (23)
#                            :              :                 :- * Project (16)
#                            :              :                 :  +- * SortMergeJoin Inner (15)
#                            :              :                 :     :- * Sort (8)
#                            :              :                 :     :  +- ShuffleQueryStage (7), Statistics(sizeInBytes=13.4 MiB, rowCount=1.76E+5)
#                            :              :                 :     :     +- Exchange (6)
#                            :              :                 :     :        +- * Filter (5)
#                            :              :                 :     :           +- * ColumnarToRow (4)
#                            :              :                 :     :              +- Scan parquet  (3)
#                            :              :                 :     +- * Sort (14)
#                            :              :                 :        +- ShuffleQueryStage (13), Statistics(sizeInBytes=158.4 MiB, rowCount=7.18E+5)
#                            :              :                 :           +- Exchange (12)
#                            :              :                 :              +- * Filter (11)
#                            :              :                 :                 +- * ColumnarToRow (10)
#                            :              :                 :                    +- Scan parquet  (9)
#                            :              :                 +- * Sort (22)
#                            :              :                    +- ShuffleQueryStage (21), Statistics(sizeInBytes=1171.3 MiB, rowCount=1.17E+7)
#                            :              :                       +- Exchange (20)
#                            :              :                          +- * Filter (19)
#                            :              :                             +- * ColumnarToRow (18)
#                            :              :                                +- Scan parquet  (17)
#                            :              +- * Sort (35)
#                            :                 +- ShuffleQueryStage (34), Statistics(sizeInBytes=788.2 MiB, rowCount=1.45E+7)
#                            :                    +- Exchange (33)
#                            :                       +- * Project (32)
#                            :                          +- * Filter (31)
#                            :                             +- * ColumnarToRow (30)
#                            :                                +- Scan parquet  (29)
#                            +- * Sort (46)
#                               +- ShuffleQueryStage (45), Statistics(sizeInBytes=3.9 GiB, rowCount=5.24E+7)
#                                  +- Exchange (44)
#                                     +- * Filter (43)
#                                        +- * ColumnarToRow (42)
#                                           +- Scan parquet  (41)
#                   +- == Initial Plan ==
#                      Project (78)
#                      +- SortMergeJoin LeftOuter (77)
#                         :- Sort (73)
#                         :  +- Exchange (72)
#                         :     +- Project (71)
#                         :        +- SortMergeJoin LeftOuter (70)
#                         :           :- Sort (65)
#                         :           :  +- Exchange (64)
#                         :           :     +- Generate (63)
#                         :           :        +- Project (62)
#                         :           :           +- SortMergeJoin LeftOuter (61)
#                         :           :              :- Project (57)
#                         :           :              :  +- SortMergeJoin Inner (56)
#                         :           :              :     :- Sort (52)
#                         :           :              :     :  +- Exchange (51)
#                         :           :              :     :     +- Filter (50)
#                         :           :              :     :        +- Scan parquet  (3)
#                         :           :              :     +- Sort (55)
#                         :           :              :        +- Exchange (54)
#                         :           :              :           +- Filter (53)
#                         :           :              :              +- Scan parquet  (9)
#                         :           :              +- Sort (60)
#                         :           :                 +- Exchange (59)
#                         :           :                    +- Filter (58)
#                         :           :                       +- Scan parquet  (17)
#                         :           +- Sort (69)
#                         :              +- Exchange (68)
#                         :                 +- Project (67)
#                         :                    +- Filter (66)
#                         :                       +- Scan parquet  (29)
#                         +- Sort (76)
#                            +- Exchange (75)
#                               +- Filter (74)
#                                  +- Scan parquet  (41)
#
#
# (1) InMemoryTableScan
# Output [5]: [primaryTitle#1058, primaryName#1081, averageRating#1053, region#1074, title#1073]
# Arguments: [primaryTitle#1058, primaryName#1081, averageRating#1053, region#1074, title#1073]
#
# (2) InMemoryRelation
# Arguments: [director_id#1099, tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070, primaryName#1081, title#1073, region#1074], StorageLevel(disk, memory, deserialized, 1 replicas)
#
# (3) Scan parquet
# Output [4]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055]
# Batched: true
# Location: InMemoryFileIndex [file:/Users/aryan/Desktop/project/data/parquet_data/title_ratings.parquet]
# PushedFilters: [IsNotNull(averageRating), GreaterThanOrEqual(averageRating,8.5), IsNotNull(tconst)]
# ReadSchema: struct<tconst:string,averageRating:double,numVotes:int,ingested_at:string>
#
# (4) ColumnarToRow [codegen id : 1]
# Input [4]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055]
#
# (5) Filter [codegen id : 1]
# Input [4]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055]
# Condition : ((isnotnull(averageRating#1053) AND (averageRating#1053 >= 8.5)) AND isnotnull(tconst#1052))
#
# (6) Exchange
# Input [4]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055]
# Arguments: hashpartitioning(tconst#1052, 8), ENSURE_REQUIREMENTS, [plan_id=1137]
#
# (7) ShuffleQueryStage
# Output [4]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055]
# Arguments: 0
#
# (8) Sort [codegen id : 6]
# Input [4]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055]
# Arguments: [tconst#1052 ASC NULLS FIRST], false, 0
#
# (9) Scan parquet
# Output [11]: [tconst#1056, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066]
# Batched: true
# Location: InMemoryFileIndex [file:/Users/aryan/Desktop/project/data/parquet_data/title_basics.parquet]
# PushedFilters: [IsNotNull(titleType), EqualTo(titleType,movie), IsNotNull(tconst)]
# ReadSchema: struct<tconst:string,titleType:string,primaryTitle:string,originalTitle:string,isAdult:string,startYear:string,endYear:string,runtimeMinutes:string,genre_1:string,genre_2:string,ingested_at:string>
#
# (10) ColumnarToRow [codegen id : 2]
# Input [11]: [tconst#1056, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066]
#
# (11) Filter [codegen id : 2]
# Input [11]: [tconst#1056, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066]
# Condition : ((isnotnull(titleType#1057) AND (titleType#1057 = movie)) AND isnotnull(tconst#1056))
#
# (12) Exchange
# Input [11]: [tconst#1056, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066]
# Arguments: hashpartitioning(tconst#1056, 8), ENSURE_REQUIREMENTS, [plan_id=1154]
#
# (13) ShuffleQueryStage
# Output [11]: [tconst#1056, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066]
# Arguments: 1
#
# (14) Sort [codegen id : 7]
# Input [11]: [tconst#1056, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066]
# Arguments: [tconst#1056 ASC NULLS FIRST], false, 0
#
# (15) SortMergeJoin [codegen id : 8]
# Left keys [1]: [tconst#1052]
# Right keys [1]: [tconst#1056]
# Join type: Inner
# Join condition: None
#
# (16) Project [codegen id : 8]
# Output [14]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066]
# Input [15]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, tconst#1056, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066]
#
# (17) Scan parquet
# Output [4]: [tconst#1067, directors#1068, writers#1069, ingested_at#1070]
# Batched: true
# Location: InMemoryFileIndex [file:/Users/aryan/Desktop/project/data/parquet_data/title_crew.parquet]
# PushedFilters: [IsNotNull(tconst)]
# ReadSchema: struct<tconst:string,directors:string,writers:string,ingested_at:string>
#
# (18) ColumnarToRow [codegen id : 3]
# Input [4]: [tconst#1067, directors#1068, writers#1069, ingested_at#1070]
#
# (19) Filter [codegen id : 3]
# Input [4]: [tconst#1067, directors#1068, writers#1069, ingested_at#1070]
# Condition : isnotnull(tconst#1067)
#
# (20) Exchange
# Input [4]: [tconst#1067, directors#1068, writers#1069, ingested_at#1070]
# Arguments: hashpartitioning(tconst#1067, 8), ENSURE_REQUIREMENTS, [plan_id=1173]
#
# (21) ShuffleQueryStage
# Output [4]: [tconst#1067, directors#1068, writers#1069, ingested_at#1070]
# Arguments: 2
#
# (22) Sort [codegen id : 9]
# Input [4]: [tconst#1067, directors#1068, writers#1069, ingested_at#1070]
# Arguments: [tconst#1067 ASC NULLS FIRST], false, 0
#
# (23) SortMergeJoin [codegen id : 10]
# Left keys [1]: [tconst#1052]
# Right keys [1]: [tconst#1067]
# Join type: LeftOuter
# Join condition: None
#
# (24) Project [codegen id : 10]
# Output [17]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070]
# Input [18]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, tconst#1067, directors#1068, writers#1069, ingested_at#1070]
#
# (25) Generate [codegen id : 10]
# Input [17]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070]
# Arguments: explode(split(directors#1068, ,, -1)), [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070], false, [director_id#1099]
#
# (26) Exchange
# Input [18]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070, director_id#1099]
# Arguments: hashpartitioning(director_id#1099, 8), ENSURE_REQUIREMENTS, [plan_id=1590]
#
# (27) ShuffleQueryStage
# Output [18]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070, director_id#1099]
# Arguments: 5
#
# (28) Sort [codegen id : 11]
# Input [18]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070, director_id#1099]
# Arguments: [director_id#1099 ASC NULLS FIRST], false, 0
#
# (29) Scan parquet
# Output [2]: [nconst#1080, primaryName#1081]
# Batched: true
# Location: InMemoryFileIndex [file:/Users/aryan/Desktop/project/data/parquet_data/name_basics.parquet]
# PushedFilters: [IsNotNull(nconst)]
# ReadSchema: struct<nconst:string,primaryName:string>
#
# (30) ColumnarToRow [codegen id : 4]
# Input [2]: [nconst#1080, primaryName#1081]
#
# (31) Filter [codegen id : 4]
# Input [2]: [nconst#1080, primaryName#1081]
# Condition : isnotnull(nconst#1080)
#
# (32) Project [codegen id : 4]
# Output [2]: [nconst#1080 AS director_id#1100, primaryName#1081]
# Input [2]: [nconst#1080, primaryName#1081]
#
# (33) Exchange
# Input [2]: [director_id#1100, primaryName#1081]
# Arguments: hashpartitioning(director_id#1100, 8), ENSURE_REQUIREMENTS, [plan_id=1197]
#
# (34) ShuffleQueryStage
# Output [2]: [director_id#1100, primaryName#1081]
# Arguments: 3
#
# (35) Sort [codegen id : 12]
# Input [2]: [director_id#1100, primaryName#1081]
# Arguments: [director_id#1100 ASC NULLS FIRST], false, 0
#
# (36) SortMergeJoin [codegen id : 13]
# Left keys [1]: [director_id#1099]
# Right keys [1]: [director_id#1100]
# Join type: LeftOuter
# Join condition: None
#
# (37) Project [codegen id : 13]
# Output [19]: [director_id#1099, tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070, primaryName#1081]
# Input [20]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070, director_id#1099, director_id#1100, primaryName#1081]
#
# (38) Exchange
# Input [19]: [director_id#1099, tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070, primaryName#1081]
# Arguments: hashpartitioning(tconst#1052, 8), ENSURE_REQUIREMENTS, [plan_id=1677]
#
# (39) ShuffleQueryStage
# Output [19]: [director_id#1099, tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070, primaryName#1081]
# Arguments: 6
#
# (40) Sort [codegen id : 14]
# Input [19]: [director_id#1099, tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070, primaryName#1081]
# Arguments: [tconst#1052 ASC NULLS FIRST], false, 0
#
# (41) Scan parquet
# Output [3]: [titleId#1071, title#1073, region#1074]
# Batched: true
# Location: InMemoryFileIndex [file:/Users/aryan/Desktop/project/data/parquet_data/title_akas.parquet]
# PushedFilters: [IsNotNull(titleId)]
# ReadSchema: struct<titleId:string,title:string,region:string>
#
# (42) ColumnarToRow [codegen id : 5]
# Input [3]: [titleId#1071, title#1073, region#1074]
#
# (43) Filter [codegen id : 5]
# Input [3]: [titleId#1071, title#1073, region#1074]
# Condition : isnotnull(titleId#1071)
#
# (44) Exchange
# Input [3]: [titleId#1071, title#1073, region#1074]
# Arguments: hashpartitioning(titleId#1071, 8), ENSURE_REQUIREMENTS, [plan_id=1225]
#
# (45) ShuffleQueryStage
# Output [3]: [titleId#1071, title#1073, region#1074]
# Arguments: 4
#
# (46) Sort [codegen id : 15]
# Input [3]: [titleId#1071, title#1073, region#1074]
# Arguments: [titleId#1071 ASC NULLS FIRST], false, 0
#
# (47) SortMergeJoin [codegen id : 16]
# Left keys [1]: [tconst#1052]
# Right keys [1]: [titleId#1071]
# Join type: LeftOuter
# Join condition: None
#
# (48) Project [codegen id : 16]
# Output [21]: [director_id#1099, tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070, primaryName#1081, title#1073, region#1074]
# Input [22]: [director_id#1099, tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070, primaryName#1081, titleId#1071, title#1073, region#1074]
#
# (49) ResultQueryStage
# Output [21]: [director_id#1099, tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070, primaryName#1081, title#1073, region#1074]
# Arguments: 7
#
# (50) Filter
# Input [4]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055]
# Condition : ((isnotnull(averageRating#1053) AND (averageRating#1053 >= 8.5)) AND isnotnull(tconst#1052))
#
# (51) Exchange
# Input [4]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055]
# Arguments: hashpartitioning(tconst#1052, 8), ENSURE_REQUIREMENTS, [plan_id=1032]
#
# (52) Sort
# Input [4]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055]
# Arguments: [tconst#1052 ASC NULLS FIRST], false, 0
#
# (53) Filter
# Input [11]: [tconst#1056, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066]
# Condition : ((isnotnull(titleType#1057) AND (titleType#1057 = movie)) AND isnotnull(tconst#1056))
#
# (54) Exchange
# Input [11]: [tconst#1056, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066]
# Arguments: hashpartitioning(tconst#1056, 8), ENSURE_REQUIREMENTS, [plan_id=1033]
#
# (55) Sort
# Input [11]: [tconst#1056, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066]
# Arguments: [tconst#1056 ASC NULLS FIRST], false, 0
#
# (56) SortMergeJoin
# Left keys [1]: [tconst#1052]
# Right keys [1]: [tconst#1056]
# Join type: Inner
# Join condition: None
#
# (57) Project
# Output [14]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066]
# Input [15]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, tconst#1056, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066]
#
# (58) Filter
# Input [4]: [tconst#1067, directors#1068, writers#1069, ingested_at#1070]
# Condition : isnotnull(tconst#1067)
#
# (59) Exchange
# Input [4]: [tconst#1067, directors#1068, writers#1069, ingested_at#1070]
# Arguments: hashpartitioning(tconst#1067, 8), ENSURE_REQUIREMENTS, [plan_id=1040]
#
# (60) Sort
# Input [4]: [tconst#1067, directors#1068, writers#1069, ingested_at#1070]
# Arguments: [tconst#1067 ASC NULLS FIRST], false, 0
#
# (61) SortMergeJoin
# Left keys [1]: [tconst#1052]
# Right keys [1]: [tconst#1067]
# Join type: LeftOuter
# Join condition: None
#
# (62) Project
# Output [17]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070]
# Input [18]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, tconst#1067, directors#1068, writers#1069, ingested_at#1070]
#
# (63) Generate
# Input [17]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070]
# Arguments: explode(split(directors#1068, ,, -1)), [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070], false, [director_id#1099]
#
# (64) Exchange
# Input [18]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070, director_id#1099]
# Arguments: hashpartitioning(director_id#1099, 8), ENSURE_REQUIREMENTS, [plan_id=1047]
#
# (65) Sort
# Input [18]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070, director_id#1099]
# Arguments: [director_id#1099 ASC NULLS FIRST], false, 0
#
# (66) Filter
# Input [2]: [nconst#1080, primaryName#1081]
# Condition : isnotnull(nconst#1080)
#
# (67) Project
# Output [2]: [nconst#1080 AS director_id#1100, primaryName#1081]
# Input [2]: [nconst#1080, primaryName#1081]
#
# (68) Exchange
# Input [2]: [director_id#1100, primaryName#1081]
# Arguments: hashpartitioning(director_id#1100, 8), ENSURE_REQUIREMENTS, [plan_id=1048]
#
# (69) Sort
# Input [2]: [director_id#1100, primaryName#1081]
# Arguments: [director_id#1100 ASC NULLS FIRST], false, 0
#
# (70) SortMergeJoin
# Left keys [1]: [director_id#1099]
# Right keys [1]: [director_id#1100]
# Join type: LeftOuter
# Join condition: None
#
# (71) Project
# Output [19]: [director_id#1099, tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070, primaryName#1081]
# Input [20]: [tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070, director_id#1099, director_id#1100, primaryName#1081]
#
# (72) Exchange
# Input [19]: [director_id#1099, tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070, primaryName#1081]
# Arguments: hashpartitioning(tconst#1052, 8), ENSURE_REQUIREMENTS, [plan_id=1055]
#
# (73) Sort
# Input [19]: [director_id#1099, tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070, primaryName#1081]
# Arguments: [tconst#1052 ASC NULLS FIRST], false, 0
#
# (74) Filter
# Input [3]: [titleId#1071, title#1073, region#1074]
# Condition : isnotnull(titleId#1071)
#
# (75) Exchange
# Input [3]: [titleId#1071, title#1073, region#1074]
# Arguments: hashpartitioning(titleId#1071, 8), ENSURE_REQUIREMENTS, [plan_id=1056]
#
# (76) Sort
# Input [3]: [titleId#1071, title#1073, region#1074]
# Arguments: [titleId#1071 ASC NULLS FIRST], false, 0
#
# (77) SortMergeJoin
# Left keys [1]: [tconst#1052]
# Right keys [1]: [titleId#1071]
# Join type: LeftOuter
# Join condition: None
#
# (78) Project
# Output [21]: [director_id#1099, tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070, primaryName#1081, title#1073, region#1074]
# Input [22]: [director_id#1099, tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070, primaryName#1081, titleId#1071, title#1073, region#1074]
#
# (79) AdaptiveSparkPlan
# Output [21]: [director_id#1099, tconst#1052, averageRating#1053, numVotes#1054, ingested_at#1055, titleType#1057, primaryTitle#1058, originalTitle#1059, isAdult#1060, startYear#1061, endYear#1062, runtimeMinutes#1063, genre_1#1064, genre_2#1065, ingested_at#1066, directors#1068, writers#1069, ingested_at#1070, primaryName#1081, title#1073, region#1074]
# Arguments: isFinalPlan=true
#
# (80) Coalesce
# Input [5]: [primaryTitle#1058, primaryName#1081, averageRating#1053, region#1074, title#1073]
# Arguments: 1
#
# (81) AdaptiveSparkPlan
# Output [5]: [primaryTitle#1058, primaryName#1081, averageRating#1053, region#1074, title#1073]
# Arguments: isFinalPlan=false

# %%
# PySpark Complex Optimization Case Study using IMDB Dataset

from pyspark.sql import SparkSession
from pyspark.sql.functions import col, split, explode, count, avg, broadcast, pandas_udf, PandasUDFType
from pyspark.sql.types import StringType
import os

# ------------------------- Spark Session -------------------------
custom_config = {
    "spark.executor.memory": "6g",
    "spark.driver.memory": "4g",
    "spark.default.parallelism": "8",
    "spark.sql.shuffle.partitions": "8",
    "spark.sql.adaptive.enabled": "true",
    "spark.sql.autoBroadcastJoinThreshold": "10485760",  # 10MB
    "spark.sql.execution.arrow.pyspark.enabled": "true"
}

spark = SparkSession.builder \
    .appName("IMDB_Advanced_Optimizations") \
    .config("spark.sql.execution.arrow.pyspark.enabled", "true") \
    .config("spark.executor.memory", custom_config["spark.executor.memory"]) \
    .config("spark.driver.memory", custom_config["spark.driver.memory"]) \
    .config("spark.default.parallelism", custom_config["spark.default.parallelism"]) \
    .config("spark.sql.shuffle.partitions", custom_config["spark.sql.shuffle.partitions"]) \
    .config("spark.sql.adaptive.enabled", custom_config["spark.sql.adaptive.enabled"]) \
    .config("spark.sql.autoBroadcastJoinThreshold", custom_config["spark.sql.autoBroadcastJoinThreshold"]) \
    .getOrCreate()

# ------------------------- Load Datasets -------------------------
base_path = "/Users/aryan/Desktop/project/data/parquet_data"

basics = spark.read.parquet(os.path.join(base_path, "title_basics.parquet"))
crew = spark.read.parquet(os.path.join(base_path, "title_crew.parquet"))
ratings = spark.read.parquet(os.path.join(base_path, "title_ratings.parquet"))
akas = spark.read.parquet(os.path.join(base_path, "title_akas.parquet"))
names = spark.read.parquet(os.path.join(base_path, "name_basics.parquet"))

# ------------------------- Optimization: Predicate Pushdown -------------------------
movies_df = basics.filter(col("titleType") == "movie")

# ------------------------- Optimization: Broadcast Join -------------------------
director_df = crew.withColumn("director_id", explode(split("directors", ",")))
name_df = names.select(col("nconst").alias("director_id"), "primaryName")

# Assume name_basics is small enough for broadcast
broadcast_name_df = broadcast(name_df)

joined_df = director_df.join(broadcast_name_df, on="director_id", how="left")

# ------------------------- Optimization: Multi Joins + Ratings -------------------------
movies_with_ratings = movies_df.join(ratings, on="tconst")

final_df = movies_with_ratings \
    .join(joined_df, on="tconst", how="left") \
    .join(akas.select("titleId", "title", "region"), movies_with_ratings.tconst == akas.titleId, how="left") \
    .drop("titleId")

# %%
# ------------------------- Optimization: Window Function + Partitioning -------------------------
from pyspark.sql.window import Window
from pyspark.sql.functions import row_number

windowSpec = Window.partitionBy("region").orderBy(col("averageRating").desc())
region_top_movies = final_df.withColumn("rank", row_number().over(windowSpec)).filter(col("rank") <= 3)

# ------------------------- Optimization: Pandas UDF -------------------------
@pandas_udf(StringType(), PandasUDFType.SCALAR)
def clean_region_code(region_series):
    return region_series.fillna("XX").str.upper()

region_top_movies = region_top_movies.withColumn("region", clean_region_code("region"))

# ------------------------- Shuffle Optimization: groupByKey vs reduceByKey -------------------------
# Simulated with rdd on genre_1
rdd = movies_df.select("genre_1", "tconst").rdd

# BAD: groupByKey (causes wide shuffle)
grouped_rdd = rdd.groupByKey().mapValues(lambda x: len(list(x)))

# GOOD: reduceByKey (combines locally before shuffle)
reduced_rdd = rdd.map(lambda x: (x[0], 1)).reduceByKey(lambda x, y: x + y)

print("Genre counts using reduceByKey:")
print(reduced_rdd.take(10))

# ------------------------- Export or Display -------------------------
region_top_movies.select("primaryTitle", "primaryName", "averageRating", "region", "title", "rank").show(truncate=False)
# Out:
# /Users/aryan/Desktop/project/venv/lib/python3.9/site-packages/pyspark/sql/pandas/functions.py:446: UserWarning: In Python 3.6+ and Spark 3.0+, it is preferred to specify type hints for pandas UDF instead of specifying pandas UDF type which will be deprecated in the future releases. See SPARK-28264 for more details.
#   warnings.warn(
# Genre counts using reduceByKey:
# [('Drama', 179774), ('Musical', 3198), ('Fantasy', 5006), ('Family', 5050), ('88', 66), ('Sport', 2160), ('86', 50), (' satsui to', 1), ('Game-Show', 20), ('113', 20)]
# 25/06/23 00:23:16 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:16 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:16 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:16 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:17 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:17 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:17 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:17 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:17 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:17 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:17 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:17 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:17 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:17 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:17 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:18 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:18 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:18 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:18 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:18 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:18 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:18 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:18 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:18 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:18 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:19 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:19 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:19 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:19 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:19 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:19 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:19 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:19 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:19 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:19 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:19 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:20 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:20 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:20 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:20 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:20 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:20 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:20 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:20 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:20 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:21 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:21 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:21 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:21 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:21 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:21 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:21 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:21 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:21 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:21 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:21 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:22 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:22 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:22 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:22 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:22 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:22 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:22 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:22 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:22 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:22 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:23 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:23 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:23 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:23 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:23 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:23 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:23 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:23 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:23 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:23 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:23 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:24 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:24 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:24 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:24 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:24 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:24 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:24 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:24 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:24 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:24 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:24 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:25 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:25 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:25 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:25 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:25 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:25 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:25 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:25 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:25 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:25 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:26 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:26 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:26 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:26 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:26 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:26 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:26 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:26 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:26 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:26 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:26 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:27 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:27 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:27 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:27 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:27 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:27 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:27 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:27 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:27 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:27 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:27 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:28 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:28 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:28 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:28 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:28 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:28 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:28 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:28 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:28 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:28 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:28 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:28 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:29 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:29 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:29 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:29 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:29 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:29 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:29 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:29 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:29 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:29 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:29 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:30 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:30 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:30 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:30 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:30 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:30 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:30 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:30 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:30 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:30 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:31 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:31 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:31 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:31 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:31 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:31 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:31 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:31 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:31 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:31 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:31 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:32 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:32 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:32 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:32 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:32 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:32 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:32 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:32 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:32 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:32 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:32 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:33 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:33 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:33 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:33 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:33 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:33 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:33 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:33 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:33 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:33 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:33 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:34 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:34 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:34 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:34 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:34 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:34 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:34 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:34 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:34 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:34 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:34 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:35 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:35 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:35 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:35 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:35 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:35 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:35 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:35 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:35 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:35 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:36 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:36 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:36 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:36 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:36 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:36 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:36 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:36 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:36 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:36 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:36 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:36 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:37 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:37 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:37 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:37 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:37 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:37 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:37 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:37 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:37 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:37 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:38 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:38 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:38 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:38 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:38 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:38 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:38 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:38 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:38 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:38 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:38 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:38 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:39 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:39 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:39 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:39 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:39 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:39 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:39 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:39 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:39 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:39 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:39 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:40 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:40 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:40 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:40 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:40 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:40 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:40 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:40 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:40 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:40 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:41 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:41 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:41 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:41 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:41 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:41 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:41 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:41 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:41 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:41 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:41 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:42 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:42 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:42 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:42 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:42 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:42 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:42 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:42 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:42 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:42 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:42 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:43 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:43 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:43 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:43 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:43 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:43 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:43 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:43 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:43 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:43 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:43 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:43 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:44 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:44 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:44 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:44 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:44 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:44 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:44 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:44 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:44 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:44 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:44 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:45 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:45 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:45 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:45 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:45 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:45 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:45 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:45 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:45 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:45 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:45 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:46 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:46 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:46 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:46 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:46 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:46 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:46 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:46 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:46 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:46 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:46 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:47 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:47 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:47 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:47 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:47 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:47 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:47 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:47 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:47 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:47 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:47 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:48 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:48 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:48 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:48 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:48 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:48 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:48 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:48 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:48 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:48 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:48 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:49 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:49 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:49 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:49 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:49 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:49 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:49 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:49 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:49 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:49 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:50 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:50 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:50 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:50 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:50 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:50 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:50 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:50 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:50 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:50 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:50 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:51 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:51 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:51 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:51 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:51 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:51 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:51 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:51 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:51 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:51 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:52 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:52 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:52 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:52 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:52 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:52 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:52 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:52 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:52 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:52 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:52 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:53 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:53 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:53 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:53 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:53 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:53 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:53 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:53 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:53 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:53 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:54 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:54 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:54 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:54 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:54 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:54 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:54 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:54 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:54 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:54 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:54 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:55 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:55 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:55 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:55 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:55 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:55 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:55 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:55 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:55 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:55 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:55 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:56 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:56 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:56 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:56 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:56 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:56 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:56 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:56 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:56 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:56 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:56 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:57 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:57 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:57 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:57 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:57 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:57 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:57 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:57 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:57 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:57 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:57 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:58 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:58 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:58 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:58 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:58 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:58 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:58 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:58 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:58 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:58 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:58 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:59 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:59 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:59 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:59 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:59 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:59 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:59 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:59 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:59 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:59 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:23:59 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:00 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:00 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:00 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:00 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:00 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:00 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:00 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:00 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:00 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:00 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:00 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:01 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:01 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:01 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:01 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# ...
# 25/06/23 00:24:44 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:45 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:45 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:45 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:45 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:45 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:45 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:45 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:45 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:45 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:45 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:46 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:46 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:46 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:46 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:46 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:46 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:46 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:46 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:46 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:46 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:46 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:47 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:47 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:47 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:47 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:47 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:47 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:47 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:47 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:47 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:47 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:47 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:48 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:48 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:48 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:48 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:48 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:48 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:48 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:48 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:48 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:48 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:49 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:49 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:49 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:49 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:49 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:49 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:49 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:49 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:49 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:49 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:49 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:50 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:50 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:50 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:50 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:50 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:50 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:50 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:50 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:50 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:50 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:50 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:51 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:51 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:51 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:51 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:51 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:51 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:51 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:51 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:51 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:51 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:51 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:52 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:52 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:52 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:52 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:52 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:52 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:52 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:52 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:52 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:52 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:52 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:53 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:53 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:53 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:53 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:53 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:53 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:53 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:53 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:53 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:53 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:54 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:54 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:54 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:54 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:54 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:54 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:54 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:54 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:54 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:54 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:55 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:55 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:55 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:55 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:55 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:55 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:55 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:55 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:55 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:56 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:56 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:56 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:56 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:56 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:56 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:56 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:56 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:56 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:56 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:57 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:57 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:57 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:57 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:57 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:57 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:57 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:57 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:57 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:57 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:58 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:58 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:58 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:58 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:58 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:58 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:58 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:58 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:58 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:58 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:58 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:59 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:59 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:59 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:59 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:59 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:59 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:59 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:59 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:59 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:24:59 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:25:00 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:25:00 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:25:00 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:25:00 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:25:00 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.
# 25/06/23 00:25:00 WARN TaskMemoryManager: Failed to allocate a page (536870912 bytes), try again.

# %%
import os
import sys

# Setup sys path to use config
sys.path.append(os.path.abspath(os.path.join(os.path.dirname("__file__"), "../../")))

from src.config import settings
from src.config.spark_config import get_spark_session
from pyspark.sql.functions import col, explode, split, count, desc
from pyspark.sql.types import StringType

# Optional: install pyarrow and pandas >= 2.0 if not already
# pip install pyarrow pandas --upgrade

# ----------------------
# Step 1: Tuning Config
# ----------------------
custom_tuning = {
    "spark.executor.memory": "8g",
    "spark.driver.memory": "6g",
    "spark.executor.cores": "4",
    "spark.sql.shuffle.partitions": "8",
    "spark.default.parallelism": "8",
    "spark.memory.fraction": "0.8",
    "spark.sql.adaptive.enabled": "true",
    "spark.sql.autoBroadcastJoinThreshold": "-1",
    "spark.sql.execution.arrow.pyspark.enabled": "true"
}

spark = get_spark_session(app_name="IMDB_Optimized_ETL", custom_config=custom_tuning)

# ----------------------
# Step 2: Load Data
# ----------------------
parquet_base = os.path.join(settings.BASE_DIR, "data", "parquet_data")
files = {
    "basics": "title_basics.parquet",
    "akas": "title_akas.parquet",
    "crew": "title_crew.parquet",
    "name": "name_basics.parquet",
    "ratings": "title_ratings.parquet"
}
df_basics = spark.read.parquet(os.path.join(parquet_base, files["basics"]))
df_crew = spark.read.parquet(os.path.join(parquet_base, files["crew"]))
df_names = spark.read.parquet(os.path.join(parquet_base, files["name"]))
df_ratings = spark.read.parquet(os.path.join(parquet_base, files["ratings"]))

# Pushdown filter (predicate pushdown happens here)
df_movies = df_basics.filter((col("titleType") == "movie") & (col("isAdult") == "0"))

# ----------------------
# Step 3: Repartition + Persist
# ----------------------
df_movies = df_movies.repartition(8).persist()
df_ratings = df_ratings.repartition(4).persist()
df_crew = df_crew.repartition(4).persist()

# ----------------------
# Step 4: Join Ratings with Movies
# ----------------------
df_joined = df_movies.join(df_ratings, on="tconst", how="inner")

# ----------------------
# Step 5: Enrich with Crew (director/writer)
# ----------------------
df_joined = df_joined.join(df_crew, on="tconst", how="left")

# ----------------------
# Step 6: Enrich with Director Name
# ----------------------
df_names = df_names.select("nconst", "primaryName").withColumnRenamed("primaryName", "directorName")

df_joined = df_joined.withColumn("director_id", split(col("directors"), ",").getItem(0))
df_joined = df_joined.join(df_names, df_joined["director_id"] == df_names["nconst"], how="left")

# ----------------------
# Step 7: Final Output - Top Rated Movies with Directors
# ----------------------
result = df_joined.select(
    "primaryTitle", "startYear", "runtimeMinutes",
    "averageRating", "numVotes", "directorName"
).orderBy(desc("averageRating"))

result.show(10, truncate=False)

# ----------------------
# Step 8: Explain Plan
# ----------------------
print("⚙️ EXPLAIN PLAN:")
result.explain(mode="formatted")

# ----------------------
# Step 9: groupByKey vs reduceByKey demo
# ----------------------
from pyspark.sql import Row
from pyspark import SparkContext

sc = spark.sparkContext

sample_data = [
    ("Drama", 1), ("Action", 1), ("Drama", 1),
    ("Comedy", 1), ("Action", 1), ("Drama", 1)
]
rdd = sc.parallelize(sample_data)

print("✅ reduceByKey (recommended):")
rdd.reduceByKey(lambda a, b: a + b).collect()

print("⚠️ groupByKey (memory heavy):")
grouped = rdd.groupByKey().mapValues(lambda x: sum(x)).collect()
# Out:
# WARNING: Using incubator modules: jdk.incubator.vector
# 25/06/23 00:26:18 WARN NativeCodeLoader: Unable to load native-hadoop library for your platform... using builtin-java classes where applicable
# Using Spark's default log4j profile: org/apache/spark/log4j2-defaults.properties
# Setting default log level to "WARN".
# To adjust logging level use sc.setLogLevel(newLevel). For SparkR, use setLogLevel(newLevel).
# /Users/aryan/Desktop/project/venv/lib/python3.9/site-packages/google/rpc/__init__.py:18: UserWarning: pkg_resources is deprecated as an API. See https://setuptools.pypa.io/en/latest/pkg_resources.html. The pkg_resources package is slated for removal as early as 2025-11-30. Refrain from using this package or pin to Setuptools<81.
#   import pkg_resources
# +-------------------------+---------+--------------+-------------+--------+----------------------------+
# |primaryTitle             |startYear|runtimeMinutes|averageRating|numVotes|directorName                |
# +-------------------------+---------+--------------+-------------+--------+----------------------------+
# |The New Guest            |2025     |\N            |10.0         |7       |Delinda Kay                 |
# |QAnon Avenue             |2024     |57            |10.0         |7       |Danny McCarthy              |
# |Kirik                    |2025     |128           |10.0         |104     |Nagathihalli Gangadhar Gowda|
# |Guru Badul               |1988     |110           |10.0         |5       |A.R. Badul                  |
# |Pandemiya                |2024     |\N            |10.0         |5       |Hilol Nasimov               |
# |One Decision             |2022     |48            |10.0         |6       |George Kirvin               |
# |Regal vs. Rebel          |2023     |\N            |10.0         |5       |Ryan Haigh                  |
# |La casa italiana         |2025     |\N            |10.0         |9       |Bob Spjuth                  |
# |NAWE ZAKHMONA            |2021     |\N            |10.0         |5       |Shahid Usman                |
# |Saybrook: The Tully Girls|2011     |67            |10.0         |10      |John MacKay                 |
# +-------------------------+---------+--------------+-------------+--------+----------------------------+
# only showing top 10 rows
# ⚙️ EXPLAIN PLAN:
# == Physical Plan ==
# AdaptiveSparkPlan (54)
# +- Sort (53)
#    +- Exchange (52)
#       +- Project (51)
#          +- SortMergeJoin LeftOuter (50)
#             :- Sort (44)
#             :  +- Exchange (43)
#             :     +- Project (42)
#             :        +- SortMergeJoin LeftOuter (41)
#             :           :- Project (28)
#             :           :  +- SortMergeJoin Inner (27)
#             :           :     :- Sort (14)
#             :           :     :  +- Exchange (13)
#             :           :     :     +- Filter (12)
#             :           :     :        +- InMemoryTableScan (1)
#             :           :     :              +- InMemoryRelation (2)
#             :           :     :                    +- AdaptiveSparkPlan (11)
#                                                       +- == Final Plan ==
#                                                          ResultQueryStage (8)
#                                                          +- ShuffleQueryStage (7), Statistics(sizeInBytes=151.6 MiB, rowCount=6.89E+5)
#                                                             +- Exchange (6)
#                                                                +- * Filter (5)
#                                                                   +- * ColumnarToRow (4)
#                                                                      +- Scan parquet  (3)
#                                                       +- == Initial Plan ==
#                                                          Exchange (10)
#                                                          +- Filter (9)
#                                                             +- Scan parquet  (3)
#             :           :     +- Sort (26)
#             :           :        +- Exchange (25)
#             :           :           +- Filter (24)
#             :           :              +- InMemoryTableScan (15)
#             :           :                    +- InMemoryRelation (16)
#             :           :                          +- AdaptiveSparkPlan (23)
#                                                       +- == Final Plan ==
#                                                          ResultQueryStage (21)
#                                                          +- ShuffleQueryStage (20), Statistics(sizeInBytes=120.5 MiB, rowCount=1.58E+6)
#                                                             +- Exchange (19)
#                                                                +- * ColumnarToRow (18)
#                                                                   +- Scan parquet  (17)
#                                                       +- == Initial Plan ==
#                                                          Exchange (22)
#                                                          +- Scan parquet  (17)
#             :           +- Sort (40)
#             :              +- Exchange (39)
#             :                 +- Filter (38)
#             :                    +- InMemoryTableScan (29)
#             :                          +- InMemoryRelation (30)
#             :                                +- AdaptiveSparkPlan (37)
#                                                 +- == Final Plan ==
#                                                    ResultQueryStage (35)
#                                                    +- ShuffleQueryStage (34), Statistics(sizeInBytes=1171.3 MiB, rowCount=1.17E+7)
#                                                       +- Exchange (33)
#                                                          +- * ColumnarToRow (32)
#                                                             +- Scan parquet  (31)
#                                                 +- == Initial Plan ==
#                                                    Exchange (36)
#                                                    +- Scan parquet  (31)
#             +- Sort (49)
#                +- Exchange (48)
#                   +- Project (47)
#                      +- Filter (46)
#                         +- Scan parquet  (45)
#
#
# (1) InMemoryTableScan
# Output [4]: [tconst#0, primaryTitle#2, startYear#5, runtimeMinutes#7]
# Arguments: [tconst#0, primaryTitle#2, startYear#5, runtimeMinutes#7], [isnotnull(tconst#0)]
#
# (2) InMemoryRelation
# Arguments: [tconst#0, titleType#1, primaryTitle#2, originalTitle#3, isAdult#4, startYear#5, endYear#6, runtimeMinutes#7, genre_1#8, genre_2#9, ingested_at#10], StorageLevel(disk, memory, deserialized, 1 replicas)
#
# (3) Scan parquet
# Output [11]: [tconst#0, titleType#1, primaryTitle#2, originalTitle#3, isAdult#4, startYear#5, endYear#6, runtimeMinutes#7, genre_1#8, genre_2#9, ingested_at#10]
# Batched: true
# Location: InMemoryFileIndex [file:/Users/aryan/Desktop/project/data/parquet_data/title_basics.parquet]
# PushedFilters: [IsNotNull(titleType), IsNotNull(isAdult), EqualTo(titleType,movie), EqualTo(isAdult,0)]
# ReadSchema: struct<tconst:string,titleType:string,primaryTitle:string,originalTitle:string,isAdult:string,startYear:string,endYear:string,runtimeMinutes:string,genre_1:string,genre_2:string,ingested_at:string>
#
# (4) ColumnarToRow [codegen id : 1]
# Input [11]: [tconst#0, titleType#1, primaryTitle#2, originalTitle#3, isAdult#4, startYear#5, endYear#6, runtimeMinutes#7, genre_1#8, genre_2#9, ingested_at#10]
#
# (5) Filter [codegen id : 1]
# Input [11]: [tconst#0, titleType#1, primaryTitle#2, originalTitle#3, isAdult#4, startYear#5, endYear#6, runtimeMinutes#7, genre_1#8, genre_2#9, ingested_at#10]
# Condition : (((isnotnull(titleType#1) AND isnotnull(isAdult#4)) AND (titleType#1 = movie)) AND (isAdult#4 = 0))
#
# (6) Exchange
# Input [11]: [tconst#0, titleType#1, primaryTitle#2, originalTitle#3, isAdult#4, startYear#5, endYear#6, runtimeMinutes#7, genre_1#8, genre_2#9, ingested_at#10]
# Arguments: RoundRobinPartitioning(8), REPARTITION_BY_NUM, [plan_id=195]
#
# (7) ShuffleQueryStage
# Output [11]: [tconst#0, titleType#1, primaryTitle#2, originalTitle#3, isAdult#4, startYear#5, endYear#6, runtimeMinutes#7, genre_1#8, genre_2#9, ingested_at#10]
# Arguments: 0
#
# (8) ResultQueryStage
# Output [11]: [tconst#0, titleType#1, primaryTitle#2, originalTitle#3, isAdult#4, startYear#5, endYear#6, runtimeMinutes#7, genre_1#8, genre_2#9, ingested_at#10]
# Arguments: 1
#
# (9) Filter
# Input [11]: [tconst#0, titleType#1, primaryTitle#2, originalTitle#3, isAdult#4, startYear#5, endYear#6, runtimeMinutes#7, genre_1#8, genre_2#9, ingested_at#10]
# Condition : (((isnotnull(titleType#1) AND isnotnull(isAdult#4)) AND (titleType#1 = movie)) AND (isAdult#4 = 0))
#
# (10) Exchange
# Input [11]: [tconst#0, titleType#1, primaryTitle#2, originalTitle#3, isAdult#4, startYear#5, endYear#6, runtimeMinutes#7, genre_1#8, genre_2#9, ingested_at#10]
# Arguments: RoundRobinPartitioning(8), REPARTITION_BY_NUM, [plan_id=12]
#
# (11) AdaptiveSparkPlan
# Output [11]: [tconst#0, titleType#1, primaryTitle#2, originalTitle#3, isAdult#4, startYear#5, endYear#6, runtimeMinutes#7, genre_1#8, genre_2#9, ingested_at#10]
# Arguments: isFinalPlan=true
#
# (12) Filter
# Input [4]: [tconst#0, primaryTitle#2, startYear#5, runtimeMinutes#7]
# Condition : isnotnull(tconst#0)
#
# (13) Exchange
# Input [4]: [tconst#0, primaryTitle#2, startYear#5, runtimeMinutes#7]
# Arguments: hashpartitioning(tconst#0, 8), ENSURE_REQUIREMENTS, [plan_id=749]
#
# (14) Sort
# Input [4]: [tconst#0, primaryTitle#2, startYear#5, runtimeMinutes#7]
# Arguments: [tconst#0 ASC NULLS FIRST], false, 0
#
# (15) InMemoryTableScan
# Output [3]: [tconst#30, averageRating#31, numVotes#32]
# Arguments: [tconst#30, averageRating#31, numVotes#32], [isnotnull(tconst#30)]
#
# (16) InMemoryRelation
# Arguments: [tconst#30, averageRating#31, numVotes#32, ingested_at#33], StorageLevel(disk, memory, deserialized, 1 replicas)
#
# (17) Scan parquet
# Output [4]: [tconst#30, averageRating#31, numVotes#32, ingested_at#33]
# Batched: true
# Location: InMemoryFileIndex [file:/Users/aryan/Desktop/project/data/parquet_data/title_ratings.parquet]
# ReadSchema: struct<tconst:string,averageRating:double,numVotes:int,ingested_at:string>
#
# (18) ColumnarToRow [codegen id : 1]
# Input [4]: [tconst#30, averageRating#31, numVotes#32, ingested_at#33]
#
# (19) Exchange
# Input [4]: [tconst#30, averageRating#31, numVotes#32, ingested_at#33]
# Arguments: RoundRobinPartitioning(4), REPARTITION_BY_NUM, [plan_id=212]
#
# (20) ShuffleQueryStage
# Output [4]: [tconst#30, averageRating#31, numVotes#32, ingested_at#33]
# Arguments: 0
#
# (21) ResultQueryStage
# Output [4]: [tconst#30, averageRating#31, numVotes#32, ingested_at#33]
# Arguments: 1
#
# (22) Exchange
# Input [4]: [tconst#30, averageRating#31, numVotes#32, ingested_at#33]
# Arguments: RoundRobinPartitioning(4), REPARTITION_BY_NUM, [plan_id=19]
#
# (23) AdaptiveSparkPlan
# Output [4]: [tconst#30, averageRating#31, numVotes#32, ingested_at#33]
# Arguments: isFinalPlan=true
#
# (24) Filter
# Input [3]: [tconst#30, averageRating#31, numVotes#32]
# Condition : isnotnull(tconst#30)
#
# (25) Exchange
# Input [3]: [tconst#30, averageRating#31, numVotes#32]
# Arguments: hashpartitioning(tconst#30, 8), ENSURE_REQUIREMENTS, [plan_id=750]
#
# (26) Sort
# Input [3]: [tconst#30, averageRating#31, numVotes#32]
# Arguments: [tconst#30 ASC NULLS FIRST], false, 0
#
# (27) SortMergeJoin
# Left keys [1]: [tconst#0]
# Right keys [1]: [tconst#30]
# Join type: Inner
# Join condition: None
#
# (28) Project
# Output [6]: [tconst#0, primaryTitle#2, startYear#5, runtimeMinutes#7, averageRating#31, numVotes#32]
# Input [7]: [tconst#0, primaryTitle#2, startYear#5, runtimeMinutes#7, tconst#30, averageRating#31, numVotes#32]
#
# (29) InMemoryTableScan
# Output [2]: [tconst#11, directors#12]
# Arguments: [tconst#11, directors#12], [isnotnull(tconst#11)]
#
# (30) InMemoryRelation
# Arguments: [tconst#11, directors#12, writers#13, ingested_at#14], StorageLevel(disk, memory, deserialized, 1 replicas)
#
# (31) Scan parquet
# Output [4]: [tconst#11, directors#12, writers#13, ingested_at#14]
# Batched: true
# Location: InMemoryFileIndex [file:/Users/aryan/Desktop/project/data/parquet_data/title_crew.parquet]
# ReadSchema: struct<tconst:string,directors:string,writers:string,ingested_at:string>
#
# (32) ColumnarToRow [codegen id : 1]
# Input [4]: [tconst#11, directors#12, writers#13, ingested_at#14]
#
# (33) Exchange
# Input [4]: [tconst#11, directors#12, writers#13, ingested_at#14]
# Arguments: RoundRobinPartitioning(4), REPARTITION_BY_NUM, [plan_id=227]
#
# (34) ShuffleQueryStage
# Output [4]: [tconst#11, directors#12, writers#13, ingested_at#14]
# Arguments: 0
#
# (35) ResultQueryStage
# Output [4]: [tconst#11, directors#12, writers#13, ingested_at#14]
# Arguments: 1
#
# (36) Exchange
# Input [4]: [tconst#11, directors#12, writers#13, ingested_at#14]
# Arguments: RoundRobinPartitioning(4), REPARTITION_BY_NUM, [plan_id=27]
#
# (37) AdaptiveSparkPlan
# Output [4]: [tconst#11, directors#12, writers#13, ingested_at#14]
# Arguments: isFinalPlan=true
#
# (38) Filter
# Input [2]: [tconst#11, directors#12]
# Condition : isnotnull(tconst#11)
#
# (39) Exchange
# Input [2]: [tconst#11, directors#12]
# Arguments: hashpartitioning(tconst#11, 8), ENSURE_REQUIREMENTS, [plan_id=757]
#
# (40) Sort
# Input [2]: [tconst#11, directors#12]
# Arguments: [tconst#11 ASC NULLS FIRST], false, 0
#
# (41) SortMergeJoin
# Left keys [1]: [tconst#0]
# Right keys [1]: [tconst#11]
# Join type: LeftOuter
# Join condition: None
#
# (42) Project
# Output [6]: [primaryTitle#2, startYear#5, runtimeMinutes#7, averageRating#31, numVotes#32, split(directors#12, ,, -1)[0] AS director_id#134]
# Input [8]: [tconst#0, primaryTitle#2, startYear#5, runtimeMinutes#7, averageRating#31, numVotes#32, tconst#11, directors#12]
#
# (43) Exchange
# Input [6]: [primaryTitle#2, startYear#5, runtimeMinutes#7, averageRating#31, numVotes#32, director_id#134]
# Arguments: hashpartitioning(director_id#134, 8), ENSURE_REQUIREMENTS, [plan_id=763]
#
# (44) Sort
# Input [6]: [primaryTitle#2, startYear#5, runtimeMinutes#7, averageRating#31, numVotes#32, director_id#134]
# Arguments: [director_id#134 ASC NULLS FIRST], false, 0
#
# (45) Scan parquet
# Output [2]: [nconst#15, primaryName#16]
# Batched: true
# Location: InMemoryFileIndex [file:/Users/aryan/Desktop/project/data/parquet_data/name_basics.parquet]
# PushedFilters: [IsNotNull(nconst)]
# ReadSchema: struct<nconst:string,primaryName:string>
#
# (46) Filter
# Input [2]: [nconst#15, primaryName#16]
# Condition : isnotnull(nconst#15)
#
# (47) Project
# Output [2]: [nconst#15, primaryName#16 AS directorName#133]
# Input [2]: [nconst#15, primaryName#16]
#
# (48) Exchange
# Input [2]: [nconst#15, directorName#133]
# Arguments: hashpartitioning(nconst#15, 8), ENSURE_REQUIREMENTS, [plan_id=764]
#
# (49) Sort
# Input [2]: [nconst#15, directorName#133]
# Arguments: [nconst#15 ASC NULLS FIRST], false, 0
#
# (50) SortMergeJoin
# Left keys [1]: [director_id#134]
# Right keys [1]: [nconst#15]
# Join type: LeftOuter
# Join condition: None
#
# (51) Project
# Output [6]: [primaryTitle#2, startYear#5, runtimeMinutes#7, averageRating#31, numVotes#32, directorName#133]
# Input [8]: [primaryTitle#2, startYear#5, runtimeMinutes#7, averageRating#31, numVotes#32, director_id#134, nconst#15, directorName#133]
#
# (52) Exchange
# Input [6]: [primaryTitle#2, startYear#5, runtimeMinutes#7, averageRating#31, numVotes#32, directorName#133]
# Arguments: rangepartitioning(averageRating#31 DESC NULLS LAST, 8), ENSURE_REQUIREMENTS, [plan_id=770]
#
# (53) Sort
# Input [6]: [primaryTitle#2, startYear#5, runtimeMinutes#7, averageRating#31, numVotes#32, directorName#133]
# Arguments: [averageRating#31 DESC NULLS LAST], true, 0
#
# (54) AdaptiveSparkPlan
# Output [6]: [primaryTitle#2, startYear#5, runtimeMinutes#7, averageRating#31, numVotes#32, directorName#133]
# Arguments: isFinalPlan=false
#
#
# ✅ reduceByKey (recommended):
# ⚠️ groupByKey (memory heavy):

# %%
# # ----------------------
# # Step 10: Optional Pandas UDF (if available)
# # ----------------------
# try:
#     import pandas as pd
#     import pyarrow

#     from pyspark.sql.functions import pandas_udf
#     from pyspark.sql.types import DoubleType

#     @pandas_udf(DoubleType())
#     def convert_minutes_to_hours(runtime: pd.Series) -> pd.Series:
#         return runtime.fillna("0").astype(float) / 60.0

#     df_with_hours = result.withColumn("runtimeHours", convert_minutes_to_hours("runtimeMinutes"))
#     df_with_hours.select("primaryTitle", "runtimeMinutes", "runtimeHours").show(5)
# except ImportError:
#     print("❌ Pandas or PyArrow not installed. Skipping vectorized UDF.")

# %%
# This is a configuration-level concept, not code-specific
print("⚙️ Vertical Scaling → More memory/cores per executor (e.g., spark.executor.memory = '6g')")
print("⚙️ Horizontal Scaling → More executors/partitions (e.g., spark.default.parallelism = 8)")
# Out:
# ⚙️ Vertical Scaling → More memory/cores per executor (e.g., spark.executor.memory = '6g')
# ⚙️ Horizontal Scaling → More executors/partitions (e.g., spark.default.parallelism = 8)

# %%
# Partition by startYear (simulates better filtering performance)
output_path = "/tmp/imdb_partitioned"
df_movies.write.partitionBy("startYear").mode("overwrite").parquet(output_path)

# Read with filter to show partition pruning
df_partitioned = spark.read.parquet(output_path)
df_2020 = df_partitioned.filter(col("startYear") == "2020")
df_2020.show(3)
# Out:
# +----------+---------+--------------------+--------------------+-------+-------+--------------+-------+-------+-------------------+---------+
# |    tconst|titleType|        primaryTitle|       originalTitle|isAdult|endYear|runtimeMinutes|genre_1|genre_2|        ingested_at|startYear|
# +----------+---------+--------------------+--------------------+-------+-------+--------------+-------+-------+-------------------+---------+
# | tt4017332|    movie|             Markham|             Markham|      0|     \N|            71| Horror|   NULL|2025-06-22 23:11:21|     2020|
# |tt33369160|    movie|Tube Light Web Se...|Tube Light Web Se...|      0|     \N|            \N| Comedy|   NULL|2025-06-22 23:11:21|     2020|
# |tt34580926|    movie|Girl Looking for ...|Girl Looking for ...|      0|     \N|           118|  Crime|  Drama|2025-06-22 23:11:21|     2020|
# +----------+---------+--------------------+--------------------+-------+-------+--------------+-------+-------+-------------------+---------+
# only showing top 3 rows

# %%
# Save table using bucketing (simulated here)
spark.sql("DROP TABLE IF EXISTS bucketed_movies")
df_movies.write.bucketBy(8, "genre_1").sortBy("primaryTitle").saveAsTable("bucketed_movies", format="parquet")

print(" Bucketed table 'bucketed_movies' created for faster joins")
# Out:
# [Stage 52:===========================================>              (6 + 2) / 8]
# ✅ Bucketed table 'bucketed_movies' created for faster joins

# %%
# Broadcast join (fast if right table is small)
df_names_small = df_names.limit(10000)

df_broadcast = df_movies.join(broadcast(df_names_small), df_movies.tconst == df_names_small.nconst, "left")
print(" Broadcast Join Count:", df_broadcast.count())

# Shuffle join (default)
df_shuffle = df_movies.join(df_names, df_movies.tconst == df_names.nconst, "left")
print("Shuffle Join Count:", df_shuffle.count())
# Out:
#  Broadcast Join Count: 688717
# Shuffle Join Count: 688717

# %%
from pyspark.sql.functions import when, rand, concat, lit

# Artificial skew
df_skewed = df_movies.withColumn("skew_key", when(col("startYear") == "2020", "high").otherwise("low"))

# Salting technique
df_skewed = df_skewed.withColumn("salt", (rand() * 10).cast("int"))
df_skewed = df_skewed.withColumn("skew_key_salted", concat(col("skew_key"), lit("_"), col("salt")))

df_skewed.groupBy("skew_key_salted").count().orderBy("count", ascending=False).show(5)
# Out:
# +---------------+-----+
# |skew_key_salted|count|
# +---------------+-----+
# |          low_2|67448|
# |          low_3|67399|
# |          low_1|67397|
# |          low_8|67346|
# |          low_6|67316|
# +---------------+-----+
# only showing top 5 rows

# %%
spark.sparkContext.setCheckpointDir("/tmp/checkpoints")
df_check = df_movies.select("primaryTitle", "startYear").checkpoint()
print("✅ Checkpoint done. Safe lineage created.")
df_check.show(3)
# Out:
# ✅ Checkpoint done. Safe lineage created.
# +--------------------+---------+
# |        primaryTitle|startYear|
# +--------------------+---------+
# |B-kyû video tsûsh...|     2000|
# |           Heartbeat|       \N|
# |    The Chess Spiral|       \N|
# +--------------------+---------+
# only showing top 3 rows

# %%
print("💡 Tip: Enable in production for straggler handling")
print("spark.conf.set('spark.speculation', 'true')")
# Out:
# 💡 Tip: Enable in production for straggler handling
# spark.conf.set('spark.speculation', 'true')
